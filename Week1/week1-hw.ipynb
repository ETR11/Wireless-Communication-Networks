# %% [markdown]
# # BL40A2030 Wireless Communication Networks
#
# ## Week 1 - Assignment
#
# ### Author: Eero Suomalainen

# %% [markdown]
# ### Part I: Theory (40%)
#
# **1. Explain with your own words (1 or 2 paragraphs) the three-layer model presented in the lecture and in [[2]](https://www.ece.rutgers.edu/~marsic/books/CN/book-CN_marsic.pdf).**
#
# **2. Retransmissions via ARQ are important to the system reliability (lower packet error probability) but it has some drawbacks. However, it has some effects in the delay and traffic congestion. Describe with your own words one of the existing trade-offs.** (Hint: If restransmissions are allowed, the packet will stay in *walking* in the network more time).

# %% [markdown]
# **1#**
#
# The three layered model portreys how data is transmitted between two end-devices in same network. On topmost layer there is specific connection between devices and their applications. In middle layer there is routing from source to destination using (most often) Internet Protocol. In the bottom layer there are exchanges of data packages between devices through (for example) Wi-Fi and Ethernet connections.
#
# **2#**
#
# More efficient the ARQ method is more complex it also is. Stop-and-Wait is a simple ARQ method as it only relies on waiting an acknowledgement (ACK) from the receiver but is not very efficient. The Selective-repeat is efficient but also complex as transmit is continuous and both the sender and the receiver must add buffer to packages and ACKs.

# %% [markdown]
# ### Part II: Jupyter NB experiments (60%)
#
# **3. Analyze a queue system similar to the tutorial considering $\lambda = 3$ and $\mu = 4$ for 2000 time periods.**
# - Plot a histogram of the queue sizes.
# - Compute the ratio of idle periods (0 elements in the queue) in relation to all time periods.
#
# **4. Analyze a queue system similar to the tutorial considering $\lambda = 4$ and $\mu = 3$ for 2000 time periods.**
# - Plot a histogram of the queue sizes.
# - Compute the ratio of idle periods (0 elements in the queue) in relation to all time periods.
#
# **5. Analyze a queue system similar to the tutorial considering $\lambda = 3$ and $\mu = 3$ for 2000 time periods.**
# - Plot a histogram of the queue sizes.
# - Compute the ratio of idle periods (0 elements in the queue) in relation to all time periods.

# %%
! pip install --upgrade numpy
! pip install --upgrade matplotlib
# Out:
# Collecting numpy
#   Downloading numpy-1.21.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 63.3 MB/s eta 0:00:0000:0100:01
# Installing collected packages: numpy
# Successfully installed numpy-1.21.6
# Collecting matplotlib
#   Downloading matplotlib-3.5.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 69.1 MB/s eta 0:00:0000:010:01
# Requirement already satisfied: numpy>=1.17 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (1.21.6)
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.4.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 82.4 MB/s eta 0:00:00:00:01
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.38.0-py3-none-any.whl (965 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 965.4/965.4 kB 68.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (2.8.2)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 67.7 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: typing-extensions in /srv/conda/envs/notebook/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib) (4.4.0)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pillow, kiwisolver, fonttools, cycler, matplotlib
# Successfully installed cycler-0.11.0 fonttools-4.38.0 kiwisolver-1.4.4 matplotlib-3.5.3 pillow-9.4.0

# %%
import numpy as np 
import matplotlib.pyplot as plt
from matplotlib import style
style.use('bmh')
#Not to show warning messages (to keep the notebook clean)
import warnings
warnings.filterwarnings('ignore')

# %%
#3

#time periods
size=2000
#Arrival
mean=3
arrival = np.random.poisson(mean, size)
#Service
mean=4
service = np.random.poisson(mean, size)
#
queue = np.zeros(size+1)

for i in range(size):
    if ((arrival[i] - service[i]) + queue[i]) > 0:
        queue[i+1] = max(0,(arrival[i] - service[i]) + queue[i])
        
idleQueue = 0

for i in range(len(queue)):
    if queue[i] == 0:
        idleQueue = idleQueue + 1

plt.figure(figsize=(14,5))
#plt.plot( arrival, 'o',label='Arrival')
#plt.plot( service, 'x',label='Sevice')
plt.plot( queue, 'ok')
plt.xlabel('$n$')
plt.ylabel('Size')
plt.title('Queue')
#plt.ylim([0, 1])
#plt.xlim([0, 10])
plt.grid(True) #grid
plt.show()

print('Idle periods ratio:', str(idleQueue)+':'+str(len(queue)))
# Out:
# Idle periods ratio: 994:2001

# %%
#4

#time periods
size=2000
#Arrival
mean=4
arrival = np.random.poisson(mean, size)
#Service
mean=3
service = np.random.poisson(mean, size)
#
queue = np.zeros(size+1)

for i in range(size):
    if ((arrival[i] - service[i]) + queue[i]) > 0:
        queue[i+1] = max(0,(arrival[i] - service[i]) + queue[i])

idleQueue = 0

for i in range(len(queue)):
    if queue[i] == 0:
        idleQueue = idleQueue + 1

plt.figure(figsize=(14,5))
#plt.plot( arrival, 'o',label='Arrival')
#plt.plot( service, 'x',label='Sevice')
plt.plot( queue, 'ok')
plt.xlabel('$n$')
plt.ylabel('Size')
plt.title('Queue')
#plt.ylim([0, 1])
#plt.xlim([0, 10])
plt.grid(True) #grid
plt.show() 

print('Idle periods ratio:', str(idleQueue)+':'+str(len(queue)))
# Out:
# Idle periods ratio: 5:2001

# %%
#5

#time periods
size=2000
#Arrival
mean=3
arrival = np.random.poisson(mean, size)
#Service
mean=3
service = np.random.poisson(mean, size)
#
queue = np.zeros(size+1)

for i in range(size):
    if ((arrival[i] - service[i]) + queue[i]) > 0:
        queue[i+1] = max(0,(arrival[i] - service[i]) + queue[i])

idleQueue = 0

for i in range(len(queue)):
    if queue[i] == 0:
        idleQueue = idleQueue + 1

plt.figure(figsize=(14,5))
#plt.plot( arrival, 'o',label='Arrival')
#plt.plot( service, 'x',label='Sevice')
plt.plot( queue, 'ok')
plt.xlabel('$n$')
plt.ylabel('Size')
plt.title('Queue')
#plt.ylim([0, 1])
#plt.xlim([0, 10])
plt.grid(True) #grid
plt.show() 

print('Idle periods ratio:', str(idleQueue)+':'+str(len(queue)))
# Out:
# Idle periods ratio: 21:2001
